# %% [markdown]
# # **Title :- "Heart-Disease Prediction"**

# %% [markdown]
# * import relevant libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# * read hear.csv file to get data

# %%
df = pd.read_csv('heart.csv')

# %%
df
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 1     49   F           NAP        160          180          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 3     48   F           ASY        138          214          0     Normal
# 4     54   M           NAP        150          195          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %% [markdown]
# * showing the head of data , 5 rows

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA        140          289          0     Normal    172
# 1   49   F           NAP        160          180          0     Normal    156
# 2   37   M           ATA        130          283          0         ST     98
# 3   48   F           ASY        138          214          0     Normal    108
# 4   54   M           NAP        150          195          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# * showing the tail of data, last 5 rows

# %%
df.tail()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 916   57   F           ATA        130          236          0        LVH
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 913    132              N      1.2     Flat             1
# 914    141              N      3.4     Flat             1
# 915    115              Y      1.2     Flat             1
# 916    174              N      0.0     Flat             1
# 917    173              N      0.0       Up             0

# %% [markdown]
# * describing the aggregate function values for each column

# %%
df.describe()
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.887364      0.553377
# std      1.066570      0.497414
# min     -2.600000      0.000000
# 25%      0.000000      0.000000
# 50%      0.600000      1.000000
# 75%      1.500000      1.000000
# max      6.200000      1.000000

# %%
df.describe(include=int)
# Out:
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean    53.510893  132.396514   198.799564    0.233115  136.809368
# std      9.432617   18.514154   109.384145    0.423046   25.460334
# min     28.000000    0.000000     0.000000    0.000000   60.000000
# 25%     47.000000  120.000000   173.250000    0.000000  120.000000
# 50%     54.000000  130.000000   223.000000    0.000000  138.000000
# 75%     60.000000  140.000000   267.000000    0.000000  156.000000
# max     77.000000  200.000000   603.000000    1.000000  202.000000
#
#        HeartDisease
# count    918.000000
# mean       0.553377
# std        0.497414
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        1.000000
# max        1.000000

# %% [markdown]
# * one sample of data

# %%
df.sample()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 144   56   F           ATA        120          279          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 144    150              N      1.0     Flat             1

# %% [markdown]
# *showing the total rows and column of data

# %%
df.shape
# Out:
# (918, 12)

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'ChestPainType', 'RestingBP', 'Cholesterol', 'FastingBS',
#        'RestingECG', 'MaxHR', 'ExerciseAngina', 'Oldpeak', 'ST_Slope',
#        'HeartDisease'],
#       dtype='object')

# %% [markdown]
# * showing the information about colum , null values and datatype

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 86.2+ KB

# %% [markdown]
# * showing the null values in each column

# %%
df.isnull()
# Out:
#        Age    Sex  ChestPainType  RestingBP  Cholesterol  FastingBS  \
# 0    False  False          False      False        False      False
# 1    False  False          False      False        False      False
# 2    False  False          False      False        False      False
# 3    False  False          False      False        False      False
# 4    False  False          False      False        False      False
# ..     ...    ...            ...        ...          ...        ...
# 913  False  False          False      False        False      False
# 914  False  False          False      False        False      False
# 915  False  False          False      False        False      False
# 916  False  False          False      False        False      False
# 917  False  False          False      False        False      False
#
#      RestingECG  MaxHR  ExerciseAngina  Oldpeak  ST_Slope  HeartDisease
# 0         False  False           False    False     False         False
# ...

# %%
df.isnull().any()
# Out:
# Age               False
# Sex               False
# ChestPainType     False
# RestingBP         False
# Cholesterol       False
# FastingBS         False
# RestingECG        False
# MaxHR             False
# ExerciseAngina    False
# Oldpeak           False
# ST_Slope          False
# HeartDisease      False
# dtype: bool

# %% [markdown]
# * count the null values in each column

# %%
df.isnull().sum()
# Out:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# * below steps shows how data presnet in the dataframe

# %%
df.loc[:3]['Age']
# Out:
# 0    40
# 1    49
# 2    37
# 3    48
# Name: Age, dtype: int64

# %%
df[df['Age']>30].shape[0]
# Out:
# 913

# %%
df[df['Age']>50].shape[0]
# Out:
# 602

# %%
df[df['Age']>60].shape[0]
# Out:
# 221

# %%
df[df['Age']>70].shape[0]
# Out:
# 24

# %% [markdown]
# * get group based on sex

# %%
data=df.groupby('Sex')

# %%
male=data.get_group('M')

# %% [markdown]
# * dataframe of male

# %%
male
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40   M           ATA        140          289          0     Normal
# 2     37   M           ATA        130          283          0         ST
# 4     54   M           NAP        150          195          0     Normal
# 5     39   M           NAP        120          339          0     Normal
# 7     54   M           ATA        110          208          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 911   59   M           ASY        164          176          1        LVH
# 913   45   M            TA        110          264          0     Normal
# 914   68   M           ASY        144          193          1     Normal
# 915   57   M           ASY        130          131          0     Normal
# 917   38   M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
female=data.get_group('F')

# %% [markdown]
# * dataframe of female

# %%
female
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 1     49   F           NAP        160          180          0     Normal
# 3     48   F           ASY        138          214          0     Normal
# 6     45   F           ATA        130          237          0     Normal
# 9     48   F           ATA        120          284          0     Normal
# 10    37   F           NAP        130          211          0     Normal
# ..   ...  ..           ...        ...          ...        ...        ...
# 901   58   F           ASY        170          225          1        LVH
# 906   55   F           ATA        132          342          0     Normal
# 909   63   F           ASY        124          197          0     Normal
# 912   57   F           ASY        140          241          0     Normal
# 916   57   F           ATA        130          236          0        LVH
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
male.shape[0]
# Out:
# 725

# %%
female.shape[0]
# Out:
# 193

# %%
df['Sex'].unique()
# Out:
# array(['M', 'F'], dtype=object)

# %%
df['Sex'].value_counts()
# Out:
# Sex
# M    725
# F    193
# Name: count, dtype: int64

# %%
df.sample()
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 620   65   M           ASY        120          177          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 620    140              N      0.4       Up             0

# %% [markdown]
# * below steps showing unique values in some column

# %%
df['ST_Slope'].value_counts()
# Out:
# ST_Slope
# Flat    460
# Up      395
# Down     63
# Name: count, dtype: int64

# %%
df['RestingECG'].value_counts()
# Out:
# RestingECG
# Normal    552
# LVH       188
# ST        178
# Name: count, dtype: int64

# %%
df['ChestPainType'].value_counts()
# Out:
# ChestPainType
# ASY    496
# NAP    203
# ATA    173
# TA      46
# Name: count, dtype: int64

# %%
df['ExerciseAngina'].value_counts()
# Out:
# ExerciseAngina
# N    547
# Y    371
# Name: count, dtype: int64

# %% [markdown]
# * check weather someone having cholestrol=0 or not , becuase no one can have 0 cholestrol

# %%
df[df['Cholesterol'] == 0]
# Out:
#      Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 293   65   M           ASY        115            0          0     Normal
# 294   32   M            TA         95            0          1     Normal
# 295   61   M           ASY        105            0          1     Normal
# 296   50   M           ASY        145            0          1     Normal
# 297   57   M           ASY        110            0          1         ST
# ..   ...  ..           ...        ...          ...        ...        ...
# 514   43   M           ASY        122            0          0     Normal
# 515   63   M           NAP        130            0          1         ST
# 518   48   M           NAP        102            0          1         ST
# 535   56   M           ASY        130            0          0        LVH
# 536   62   M           NAP        133            0          1         ST
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# ...

# %%
df.shape[0]-df[df['Cholesterol'] == 0].shape[0]
# Out:
# 746

# %%
((df[df['Cholesterol'] == 0].shape[0])*100)/(df['Cholesterol'].shape[0])
# Out:
# 18.736383442265794

# %% [markdown]
# * replace cholestrol=0 with mean of cholestrol column

# %%
cholesterol_mean = df.loc[df['Cholesterol'] != 0, 'Cholesterol'].mean()

# Step 2: Replace 0s with the calculated mean
df['Cholesterol'] = df['Cholesterol'].replace(0, cholesterol_mean)

# Optional: Round to 2 decimal places (if needed)
df['Cholesterol'] = df['Cholesterol'].round(2)

# %% [markdown]
# * check weather someone having RestingBP=0 or not , becuase no one can have 0 RestingBP
# * fill RestingBP with its mean

# %%
resting_bp_mean = df.loc[df['RestingBP'] != 0, 'RestingBP'].mean()

df['RestingBP'] = df['RestingBP'].replace(0, resting_bp_mean)

df['RestingBP'] = df['RestingBP'].round(2)

# %% [markdown]
# * below steps for visiulization of data

# %% [markdown]
# * bar-chart for heartdisease

# %%
df['HeartDisease'].value_counts().plot(kind = 'bar')
# Out:
# <Axes: xlabel='HeartDisease'>

# %% [markdown]
# * plotting the histplot for age,restingbp,cholestroland maxhr

# %%
def plotting(var,num):
    plt.subplot(2,2,num)
    sns.histplot(df[var],kde = True)

plotting("Age",1)
plotting("RestingBP",2)
plotting("Cholesterol",3)
plotting("MaxHR",4)

plt.tight_layout()

# %% [markdown]
# * countplot for gender(sex)

# %%
sns.countplot(x = df['Sex'])
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x = df['ChestPainType'],hue = df['HeartDisease'])
# Out:
# <Axes: xlabel='ChestPainType', ylabel='count'>

# %%
sns.countplot(x = df['FastingBS'],hue = df['HeartDisease'])
# Out:
# <Axes: xlabel='FastingBS', ylabel='count'>

# %% [markdown]
# * boxplot for heardieases to find outliers

# %%
sns.boxplot(x='HeartDisease', y='Cholesterol', data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Cholesterol'>

# %% [markdown]
# * violinplot for heartdisease to check density

# %%
sns.violinplot(x='HeartDisease', y='Age', data=df)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='Age'>

# %% [markdown]
# * heatmap to find correlation between column only for numeric values column

# %%
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# * below steps involve preprocessing of data to train the model

# %%
df.head()
# Out:
#    Age Sex ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  MaxHR  \
# 0   40   M           ATA      140.0        289.0          0     Normal    172
# 1   49   F           NAP      160.0        180.0          0     Normal    156
# 2   37   M           ATA      130.0        283.0          0         ST     98
# 3   48   F           ASY      138.0        214.0          0     Normal    108
# 4   54   M           NAP      150.0        195.0          0     Normal    122
#
#   ExerciseAngina  Oldpeak ST_Slope  HeartDisease
# 0              N      0.0       Up             0
# 1              N      1.0     Flat             1
# 2              N      0.0       Up             0
# 3              Y      1.5     Flat             1
# 4              N      0.0       Up             0

# %% [markdown]
# * getting the dummy column for each unique values in each column

# %%
df_encoded = pd.get_dummies(df,drop_first=True)

# %%
df_encoded
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40      140.0        289.0          0    172      0.0             0
# 1     49      160.0        180.0          0    156      1.0             1
# 2     37      130.0        283.0          0     98      0.0             0
# 3     48      138.0        214.0          0    108      1.5             1
# 4     54      150.0        195.0          0    122      0.0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45      110.0        264.0          0    132      1.2             1
# 914   68      144.0        193.0          1    141      3.4             1
# 915   57      130.0        131.0          0    115      1.2             1
# 916   57      130.0        236.0          0    174      0.0             1
# 917   38      138.0        175.0          0    173      0.0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %% [markdown]
# * making datatype int for each column

# %%
df_encoded = df_encoded.astype(int)

# %%
df_encoded
# Out:
#      Age  RestingBP  Cholesterol  FastingBS  MaxHR  Oldpeak  HeartDisease  \
# 0     40        140          289          0    172        0             0
# 1     49        160          180          0    156        1             1
# 2     37        130          283          0     98        0             0
# 3     48        138          214          0    108        1             1
# 4     54        150          195          0    122        0             0
# ..   ...        ...          ...        ...    ...      ...           ...
# 913   45        110          264          0    132        1             1
# 914   68        144          193          1    141        3             1
# 915   57        130          131          0    115        1             1
# 916   57        130          236          0    174        0             1
# 917   38        138          175          0    173        0             0
#
#      Sex_M  ChestPainType_ATA  ChestPainType_NAP  ChestPainType_TA  \
# ...

# %% [markdown]
# * showing column after creating dummy column

# %%
df_encoded.columns
# Out:
# Index(['Age', 'RestingBP', 'Cholesterol', 'FastingBS', 'MaxHR', 'Oldpeak',
#        'HeartDisease', 'Sex_M', 'ChestPainType_ATA', 'ChestPainType_NAP',
#        'ChestPainType_TA', 'RestingECG_Normal', 'RestingECG_ST',
#        'ExerciseAngina_Y', 'ST_Slope_Flat', 'ST_Slope_Up'],
#       dtype='object')

# %% [markdown]
# * importing sklearn libraries and model classis

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, f1_score, classification_report
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# * create x and y axes

# %%
X = df_encoded.drop('HeartDisease', axis=1)
y = df_encoded['HeartDisease']

# %% [markdown]
# * split data for traing and testing

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, stratify=y, test_size=0.2, random_state=42)

# %% [markdown]
# * scale data into uniform range for better output

# %%
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %% [markdown]
# * make a list of relevant models

# %%
models = {
    "Logistic Regression": LogisticRegression(),
    "KNN": KNeighborsClassifier(),
    "Naive Bayes": GaussianNB(),
    "Decision Tree": DecisionTreeClassifier(),
    "SVM (RBF Kernel)": SVC(probability=True)
}

# %%
results = []

# %% [markdown]
# * applying for loop to train each model and getting its accuracy , r1-score etc and store into result list

# %%
for name, model in models.items():
    model.fit(X_train_scaled, y_train)
    y_pred = model.predict(X_test_scaled)
    acc = accuracy_score(y_test, y_pred)
    f1 = f1_score(y_test, y_pred)
    results.append({
        'Model': name,
        'Accuracy': round(acc, 4),
        'F1 Score': round(f1, 4)
    })

# %% [markdown]
# * shwoing the list results

# %%
results
# Out:
# [{'Model': 'Logistic Regression', 'Accuracy': 0.875, 'F1 Score': 0.8878},
#  {'Model': 'KNN', 'Accuracy': 0.8859, 'F1 Score': 0.8986},
#  {'Model': 'Naive Bayes', 'Accuracy': 0.8696, 'F1 Score': 0.8788},
#  {'Model': 'Decision Tree', 'Accuracy': 0.7609, 'F1 Score': 0.7708},
#  {'Model': 'SVM (RBF Kernel)', 'Accuracy': 0.8641, 'F1 Score': 0.8804}]

# %% [markdown]
# * above knn model is best fit for data and predict relevant output

# %%
import joblib
joblib.dump(models['KNN'],'KNN_heart.pkl')
joblib.dump(scaler,'scaler.pkl')
joblib.dump(X.columns.tolist(),'columns.pkl')
# Out:
# ['columns.pkl']
